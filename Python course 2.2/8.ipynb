# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('D:/graphic.xlsx')
plt.plot(df['a'], df['b'])
plt.savefig('you_plot_image.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
